# %%
#(2.1) モデルのダウンロード（BD_Marumi LoRA）
# !mkdir -p /notebooks/stable-diffusion-webui/models/Lora
# %cd /notebooks/stable-diffusion-webui/models/Lora
# !wget -nc https://civitai.com/api/download/models/75569 -O BD_marumi_v3.safetensors
