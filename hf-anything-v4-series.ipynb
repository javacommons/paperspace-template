# %%
#(2.1) モデルのダウンロード（Anything-V4 series (huggingface)）
# %cd /notebooks/stable-diffusion-webui/models/Stable-diffusion
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned-fp16.safetensors -O hf-anything-v4.0-pruned-fp16.safetensors
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned-fp32.safetensors -O hf-anything-v4.0-pruned-fp32.safetensors
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.safetensors      -O hf-anything-v4.0-pruned.safetensors
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned-fp16.ckpt        -O hf-anything-v4.5-pruned-fp16.ckpt
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned-fp32.ckpt        -O hf-anything-v4.5-pruned-fp32.ckpt
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.ckpt             -O hf-anything-v4.5-pruned.ckpt

# %cd /notebooks/stable-diffusion-webui/models/VAE
# !wget -nc https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt                  -O anything-v4.0.vae.pt
